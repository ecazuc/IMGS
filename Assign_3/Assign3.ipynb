# %%
import torch
from torch import nn
from d2l import torch as d2l

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=5, padding=2), nn.Sigmoid(),
            nn.AvgPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.Sigmoid(),
            nn.AvgPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.Sigmoid(),
            nn.LazyLinear(84), nn.Sigmoid(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 28, 28])
# Sigmoid output shape:	 torch.Size([1, 6, 28, 28])
# AvgPool2d output shape:	 torch.Size([1, 6, 14, 14])
# Conv2d output shape:	 torch.Size([1, 16, 10, 10])
# Sigmoid output shape:	 torch.Size([1, 16, 10, 10])
# AvgPool2d output shape:	 torch.Size([1, 16, 5, 5])
# Flatten output shape:	 torch.Size([1, 400])
# Linear output shape:	 torch.Size([1, 120])
# Sigmoid output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# Sigmoid output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])
# C:\Users\ewenc\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=5, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 28, 28])
# ReLU output shape:	 torch.Size([1, 6, 28, 28])
# MaxPool2d output shape:	 torch.Size([1, 6, 14, 14])
# Conv2d output shape:	 torch.Size([1, 16, 10, 10])
# ReLU output shape:	 torch.Size([1, 16, 10, 10])
# MaxPool2d output shape:	 torch.Size([1, 16, 5, 5])
# Flatten output shape:	 torch.Size([1, 400])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=7, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 26, 26])
# ReLU output shape:	 torch.Size([1, 6, 26, 26])
# MaxPool2d output shape:	 torch.Size([1, 6, 13, 13])
# Conv2d output shape:	 torch.Size([1, 16, 9, 9])
# ReLU output shape:	 torch.Size([1, 16, 9, 9])
# MaxPool2d output shape:	 torch.Size([1, 16, 4, 4])
# Flatten output shape:	 torch.Size([1, 256])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=3, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 30, 30])
# ReLU output shape:	 torch.Size([1, 6, 30, 30])
# MaxPool2d output shape:	 torch.Size([1, 6, 15, 15])
# Conv2d output shape:	 torch.Size([1, 16, 11, 11])
# ReLU output shape:	 torch.Size([1, 16, 11, 11])
# MaxPool2d output shape:	 torch.Size([1, 16, 5, 5])
# Flatten output shape:	 torch.Size([1, 400])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=7, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=7), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 26, 26])
# ReLU output shape:	 torch.Size([1, 6, 26, 26])
# MaxPool2d output shape:	 torch.Size([1, 6, 13, 13])
# Conv2d output shape:	 torch.Size([1, 16, 7, 7])
# ReLU output shape:	 torch.Size([1, 16, 7, 7])
# MaxPool2d output shape:	 torch.Size([1, 16, 3, 3])
# Flatten output shape:	 torch.Size([1, 144])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=7, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=2),
            nn.LazyConv2d(16, kernel_size=7), nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 26, 26])
# ReLU output shape:	 torch.Size([1, 6, 26, 26])
# MaxPool2d output shape:	 torch.Size([1, 6, 12, 12])
# Conv2d output shape:	 torch.Size([1, 16, 6, 6])
# ReLU output shape:	 torch.Size([1, 16, 6, 6])
# MaxPool2d output shape:	 torch.Size([1, 16, 2, 2])
# Flatten output shape:	 torch.Size([1, 64])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=8, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=2),
            nn.LazyConv2d(16, kernel_size=8), nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 25, 25])
# ReLU output shape:	 torch.Size([1, 6, 25, 25])
# MaxPool2d output shape:	 torch.Size([1, 6, 11, 11])
# Conv2d output shape:	 torch.Size([1, 16, 4, 4])
# ReLU output shape:	 torch.Size([1, 16, 4, 4])
# MaxPool2d output shape:	 torch.Size([1, 16, 1, 1])
# Flatten output shape:	 torch.Size([1, 16])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=7, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=5, stride=2),
            nn.LazyConv2d(16, kernel_size=7), nn.ReLU(),
            nn.MaxPool2d(kernel_size=5, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 26, 26])
# ReLU output shape:	 torch.Size([1, 6, 26, 26])
# MaxPool2d output shape:	 torch.Size([1, 6, 11, 11])
# Conv2d output shape:	 torch.Size([1, 16, 5, 5])
# ReLU output shape:	 torch.Size([1, 16, 5, 5])
# MaxPool2d output shape:	 torch.Size([1, 16, 1, 1])
# Flatten output shape:	 torch.Size([1, 16])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=3, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=5, stride=2),
            nn.LazyConv2d(16, kernel_size=3), nn.ReLU(),
            nn.MaxPool2d(kernel_size=5, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 30, 30])
# ReLU output shape:	 torch.Size([1, 6, 30, 30])
# MaxPool2d output shape:	 torch.Size([1, 6, 13, 13])
# Conv2d output shape:	 torch.Size([1, 16, 11, 11])
# ReLU output shape:	 torch.Size([1, 16, 11, 11])
# MaxPool2d output shape:	 torch.Size([1, 16, 4, 4])
# Flatten output shape:	 torch.Size([1, 256])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(16, kernel_size=7, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 16, 26, 26])
# ReLU output shape:	 torch.Size([1, 16, 26, 26])
# MaxPool2d output shape:	 torch.Size([1, 16, 13, 13])
# Conv2d output shape:	 torch.Size([1, 16, 9, 9])
# ReLU output shape:	 torch.Size([1, 16, 9, 9])
# MaxPool2d output shape:	 torch.Size([1, 16, 4, 4])
# Flatten output shape:	 torch.Size([1, 256])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=3, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=7), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 30, 30])
# ReLU output shape:	 torch.Size([1, 6, 30, 30])
# MaxPool2d output shape:	 torch.Size([1, 6, 15, 15])
# Conv2d output shape:	 torch.Size([1, 16, 9, 9])
# ReLU output shape:	 torch.Size([1, 16, 9, 9])
# MaxPool2d output shape:	 torch.Size([1, 16, 4, 4])
# Flatten output shape:	 torch.Size([1, 256])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=3, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 30, 30])
# ReLU output shape:	 torch.Size([1, 6, 30, 30])
# MaxPool2d output shape:	 torch.Size([1, 6, 15, 15])
# Conv2d output shape:	 torch.Size([1, 16, 11, 11])
# ReLU output shape:	 torch.Size([1, 16, 11, 11])
# MaxPool2d output shape:	 torch.Size([1, 16, 5, 5])
# Flatten output shape:	 torch.Size([1, 400])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


    # Define a method to evaluate and print errors
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=7, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(6, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 26, 26])
# ReLU output shape:	 torch.Size([1, 6, 26, 26])
# MaxPool2d output shape:	 torch.Size([1, 6, 13, 13])
# Conv2d output shape:	 torch.Size([1, 6, 9, 9])
# ReLU output shape:	 torch.Size([1, 6, 9, 9])
# MaxPool2d output shape:	 torch.Size([1, 6, 4, 4])
# Flatten output shape:	 torch.Size([1, 96])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)

# %%
model.evaluate_and_print_errors(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 model.evaluate_and_print_errors(data)
#
# Cell In[50], line 5, in evaluate_and_print_errors(self, data)
#       1 @d2l.add_to_class(d2l.Classifier)  #@save
#       2
#       3     # Define a method to evaluate and print errors
#       4 def evaluate_and_print_errors(self, data):
# ----> 5     train_metrics = self.evaluate(data.get_dataloader(True))
#       6     test_metrics = self.evaluate(data.get_dataloader(False))
#       7     print("Train error:", 1 - train_metrics['accuracy'])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1614, in Module.__getattr__(self, name)
#    1612     if name in modules:
#    1613         return modules[name]
# -> 1614 raise AttributeError("'{}' object has no attribute '{}'".format(
# ...

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=7, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


    # Define a method to evaluate and print errors
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 26, 26])
# ReLU output shape:	 torch.Size([1, 10, 26, 26])
# MaxPool2d output shape:	 torch.Size([1, 10, 13, 13])
# Conv2d output shape:	 torch.Size([1, 16, 9, 9])
# ReLU output shape:	 torch.Size([1, 16, 9, 9])
# MaxPool2d output shape:	 torch.Size([1, 16, 4, 4])
# Flatten output shape:	 torch.Size([1, 256])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)

# %%
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.10099999999999998
# Test error: 0.12039999999999995

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=7, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 26, 26])
# ReLU output shape:	 torch.Size([1, 10, 26, 26])
# MaxPool2d output shape:	 torch.Size([1, 10, 13, 13])
# Conv2d output shape:	 torch.Size([1, 16, 9, 9])
# ReLU output shape:	 torch.Size([1, 16, 9, 9])
# MaxPool2d output shape:	 torch.Size([1, 16, 4, 4])
# Flatten output shape:	 torch.Size([1, 256])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.09133333333333338
# Test error: 0.11060000000000003

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=3, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 30, 30])
# ReLU output shape:	 torch.Size([1, 10, 30, 30])
# MaxPool2d output shape:	 torch.Size([1, 10, 15, 15])
# Conv2d output shape:	 torch.Size([1, 16, 11, 11])
# ReLU output shape:	 torch.Size([1, 16, 11, 11])
# MaxPool2d output shape:	 torch.Size([1, 16, 5, 5])
# Flatten output shape:	 torch.Size([1, 400])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.09006666666666663
# Test error: 0.10719999999999996

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=5, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=3), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 28, 28])
# ReLU output shape:	 torch.Size([1, 10, 28, 28])
# MaxPool2d output shape:	 torch.Size([1, 10, 14, 14])
# Conv2d output shape:	 torch.Size([1, 16, 12, 12])
# ReLU output shape:	 torch.Size([1, 16, 12, 12])
# MaxPool2d output shape:	 torch.Size([1, 16, 6, 6])
# Flatten output shape:	 torch.Size([1, 576])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.0884666666666667
# Test error: 0.10709999999999997

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=5, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=7), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 28, 28])
# ReLU output shape:	 torch.Size([1, 10, 28, 28])
# MaxPool2d output shape:	 torch.Size([1, 10, 14, 14])
# Conv2d output shape:	 torch.Size([1, 16, 8, 8])
# ReLU output shape:	 torch.Size([1, 16, 8, 8])
# MaxPool2d output shape:	 torch.Size([1, 16, 4, 4])
# Flatten output shape:	 torch.Size([1, 256])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.08445000000000003
# Test error: 0.11129999999999995

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=3, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=3), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 30, 30])
# ReLU output shape:	 torch.Size([1, 10, 30, 30])
# MaxPool2d output shape:	 torch.Size([1, 10, 15, 15])
# Conv2d output shape:	 torch.Size([1, 16, 13, 13])
# ReLU output shape:	 torch.Size([1, 16, 13, 13])
# MaxPool2d output shape:	 torch.Size([1, 16, 6, 6])
# Flatten output shape:	 torch.Size([1, 576])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.09714999999999996
# Test error: 0.11509999999999998

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=7, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=7), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 26, 26])
# ReLU output shape:	 torch.Size([1, 10, 26, 26])
# MaxPool2d output shape:	 torch.Size([1, 10, 13, 13])
# Conv2d output shape:	 torch.Size([1, 16, 7, 7])
# ReLU output shape:	 torch.Size([1, 16, 7, 7])
# MaxPool2d output shape:	 torch.Size([1, 16, 3, 3])
# Flatten output shape:	 torch.Size([1, 144])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.09299999999999997
# Test error: 0.11360000000000003

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=5, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 28, 28])
# ReLU output shape:	 torch.Size([1, 10, 28, 28])
# MaxPool2d output shape:	 torch.Size([1, 10, 14, 14])
# Conv2d output shape:	 torch.Size([1, 16, 10, 10])
# ReLU output shape:	 torch.Size([1, 16, 10, 10])
# MaxPool2d output shape:	 torch.Size([1, 16, 5, 5])
# Flatten output shape:	 torch.Size([1, 400])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.08673333333333333
# Test error: 0.10880000000000001

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=3, padding=2), nn.ReLU(),
            nn.LazyConv2d(10, kernel_size=3, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=5),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 30, 30])
# ReLU output shape:	 torch.Size([1, 10, 30, 30])
# Conv2d output shape:	 torch.Size([1, 10, 32, 32])
# ReLU output shape:	 torch.Size([1, 10, 32, 32])
# MaxPool2d output shape:	 torch.Size([1, 10, 16, 16])
# Conv2d output shape:	 torch.Size([1, 16, 12, 12])
# ReLU output shape:	 torch.Size([1, 16, 12, 12])
# MaxPool2d output shape:	 torch.Size([1, 16, 3, 3])
# Flatten output shape:	 torch.Size([1, 144])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.08863333333333334
# Test error: 0.10570000000000002

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=3, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=5),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 30, 30])
# ReLU output shape:	 torch.Size([1, 10, 30, 30])
# MaxPool2d output shape:	 torch.Size([1, 10, 15, 15])
# Conv2d output shape:	 torch.Size([1, 16, 11, 11])
# ReLU output shape:	 torch.Size([1, 16, 11, 11])
# Conv2d output shape:	 torch.Size([1, 16, 7, 7])
# ReLU output shape:	 torch.Size([1, 16, 7, 7])
# MaxPool2d output shape:	 torch.Size([1, 16, 2, 2])
# Flatten output shape:	 torch.Size([1, 64])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.09325000000000006
# Test error: 0.11060000000000003

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=3, padding=2), nn.ReLU(),
            nn.LazyConv2d(10, kernel_size=3, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=5),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 30, 30])
# ReLU output shape:	 torch.Size([1, 10, 30, 30])
# Conv2d output shape:	 torch.Size([1, 10, 32, 32])
# ReLU output shape:	 torch.Size([1, 10, 32, 32])
# MaxPool2d output shape:	 torch.Size([1, 10, 16, 16])
# Conv2d output shape:	 torch.Size([1, 16, 12, 12])
# ReLU output shape:	 torch.Size([1, 16, 12, 12])
# Conv2d output shape:	 torch.Size([1, 16, 8, 8])
# ReLU output shape:	 torch.Size([1, 16, 8, 8])
# MaxPool2d output shape:	 torch.Size([1, 16, 2, 2])
# Flatten output shape:	 torch.Size([1, 64])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.10734999999999995
# Test error: 0.122

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=3, padding=2), nn.ReLU(),
            nn.LazyConv2d(10, kernel_size=3, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=5),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 30, 30])
# ReLU output shape:	 torch.Size([1, 6, 30, 30])
# Conv2d output shape:	 torch.Size([1, 10, 32, 32])
# ReLU output shape:	 torch.Size([1, 10, 32, 32])
# MaxPool2d output shape:	 torch.Size([1, 10, 16, 16])
# Conv2d output shape:	 torch.Size([1, 16, 12, 12])
# ReLU output shape:	 torch.Size([1, 16, 12, 12])
# Conv2d output shape:	 torch.Size([1, 16, 8, 8])
# ReLU output shape:	 torch.Size([1, 16, 8, 8])
# MaxPool2d output shape:	 torch.Size([1, 16, 2, 2])
# Flatten output shape:	 torch.Size([1, 64])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.09399999999999997
# Test error: 0.11429999999999996

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=3, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=5),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 30, 30])
# ReLU output shape:	 torch.Size([1, 6, 30, 30])
# MaxPool2d output shape:	 torch.Size([1, 6, 15, 15])
# Conv2d output shape:	 torch.Size([1, 16, 11, 11])
# ReLU output shape:	 torch.Size([1, 16, 11, 11])
# MaxPool2d output shape:	 torch.Size([1, 16, 2, 2])
# Flatten output shape:	 torch.Size([1, 64])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.14634999999999998
# Test error: 0.16369999999999996

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=3, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=5),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 30, 30])
# ReLU output shape:	 torch.Size([1, 6, 30, 30])
# MaxPool2d output shape:	 torch.Size([1, 6, 15, 15])
# Conv2d output shape:	 torch.Size([1, 16, 11, 11])
# ReLU output shape:	 torch.Size([1, 16, 11, 11])
# MaxPool2d output shape:	 torch.Size([1, 16, 2, 2])
# Flatten output shape:	 torch.Size([1, 64])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.1336666666666667
# Test error: 0.15069999999999995

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=3, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=5),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(52), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 30, 30])
# ReLU output shape:	 torch.Size([1, 6, 30, 30])
# MaxPool2d output shape:	 torch.Size([1, 6, 15, 15])
# Conv2d output shape:	 torch.Size([1, 16, 11, 11])
# ReLU output shape:	 torch.Size([1, 16, 11, 11])
# MaxPool2d output shape:	 torch.Size([1, 16, 2, 2])
# Flatten output shape:	 torch.Size([1, 64])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 52])
# ReLU output shape:	 torch.Size([1, 52])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.13403333333333334
# Test error: 0.15069999999999995

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(6, kernel_size=3, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=5),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 6, 30, 30])
# ReLU output shape:	 torch.Size([1, 6, 30, 30])
# MaxPool2d output shape:	 torch.Size([1, 6, 15, 15])
# Conv2d output shape:	 torch.Size([1, 16, 11, 11])
# ReLU output shape:	 torch.Size([1, 16, 11, 11])
# MaxPool2d output shape:	 torch.Size([1, 16, 2, 2])
# Flatten output shape:	 torch.Size([1, 64])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.13706666666666667
# Test error: 0.15159999999999996

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=5, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 28, 28])
# ReLU output shape:	 torch.Size([1, 10, 28, 28])
# MaxPool2d output shape:	 torch.Size([1, 10, 14, 14])
# Conv2d output shape:	 torch.Size([1, 16, 10, 10])
# ReLU output shape:	 torch.Size([1, 16, 10, 10])
# MaxPool2d output shape:	 torch.Size([1, 16, 5, 5])
# Flatten output shape:	 torch.Size([1, 400])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.08255000000000001
# Test error: 0.10429999999999995

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=5, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 28, 28])
# ReLU output shape:	 torch.Size([1, 10, 28, 28])
# MaxPool2d output shape:	 torch.Size([1, 10, 14, 14])
# Conv2d output shape:	 torch.Size([1, 16, 10, 10])
# ReLU output shape:	 torch.Size([1, 16, 10, 10])
# MaxPool2d output shape:	 torch.Size([1, 16, 5, 5])
# Flatten output shape:	 torch.Size([1, 400])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.08755000000000002
# Test error: 0.10960000000000003

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=5, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 28, 28])
# ReLU output shape:	 torch.Size([1, 10, 28, 28])
# MaxPool2d output shape:	 torch.Size([1, 10, 14, 14])
# Conv2d output shape:	 torch.Size([1, 16, 10, 10])
# ReLU output shape:	 torch.Size([1, 16, 10, 10])
# MaxPool2d output shape:	 torch.Size([1, 16, 5, 5])
# Flatten output shape:	 torch.Size([1, 400])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.10323333333333329
# Test error: 0.12070000000000003

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=5, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(62), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 28, 28])
# ReLU output shape:	 torch.Size([1, 10, 28, 28])
# MaxPool2d output shape:	 torch.Size([1, 10, 14, 14])
# Conv2d output shape:	 torch.Size([1, 16, 10, 10])
# ReLU output shape:	 torch.Size([1, 16, 10, 10])
# MaxPool2d output shape:	 torch.Size([1, 16, 5, 5])
# Flatten output shape:	 torch.Size([1, 400])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 62])
# ReLU output shape:	 torch.Size([1, 62])
# Linear output shape:	 torch.Size([1, 10])

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.0910833333333333
# Test error: 0.11480000000000001

# %%
def init_cnn(module):  #@save
    """Initialize weights for CNNs."""
    if type(module) == nn.Linear or type(module) == nn.Conv2d:
        nn.init.xavier_uniform_(module.weight)

class LeNet(d2l.Classifier):  #@save
    """The LeNet-5 model."""
    def __init__(self, lr=0.1, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.LazyConv2d(10, kernel_size=5, padding=2), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.LazyConv2d(16, kernel_size=5), nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.LazyLinear(120), nn.ReLU(),
            nn.LazyLinear(84), nn.ReLU(),
            nn.LazyLinear(num_classes))

# %%
@d2l.add_to_class(d2l.Classifier)  #@save

def evaluate(self, data_iter):
        acc_sum, n = 0, 0
        with torch.no_grad():
            for X, y in data_iter:
                y_hat = self(X)
                acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
                n += y.shape[0]
        return {'accuracy': acc_sum / n}


@d2l.add_to_class(d2l.Classifier)  #@save
def evaluate_and_print_errors(self, data):
    train_metrics = self.evaluate(data.get_dataloader(True))
    test_metrics = self.evaluate(data.get_dataloader(False))
    print("Train error:", 1 - train_metrics['accuracy'])
    print("Test error:", 1 - test_metrics['accuracy'])

# %%
@d2l.add_to_class(d2l.Classifier)  #@save
def layer_summary(self, X_shape):
    X = torch.randn(*X_shape)
    for layer in self.net:
        X = layer(X)
        print(layer.__class__.__name__, 'output shape:\t', X.shape)

model = LeNet()
model.layer_summary((1, 1, 28, 28))
# Out:
# Conv2d output shape:	 torch.Size([1, 10, 28, 28])
# ReLU output shape:	 torch.Size([1, 10, 28, 28])
# MaxPool2d output shape:	 torch.Size([1, 10, 14, 14])
# Conv2d output shape:	 torch.Size([1, 16, 10, 10])
# ReLU output shape:	 torch.Size([1, 16, 10, 10])
# MaxPool2d output shape:	 torch.Size([1, 16, 5, 5])
# Flatten output shape:	 torch.Size([1, 400])
# Linear output shape:	 torch.Size([1, 120])
# ReLU output shape:	 torch.Size([1, 120])
# Linear output shape:	 torch.Size([1, 84])
# ReLU output shape:	 torch.Size([1, 84])
# Linear output shape:	 torch.Size([1, 10])
# C:\Users\ewenc\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %%
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.2)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.08884999999999998
# Test error: 0.11229999999999996

# %%
trainer = d2l.Trainer(max_epochs=15, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.07118333333333338
# Test error: 0.09730000000000005

# %%
trainer = d2l.Trainer(max_epochs=15, num_gpus=1)
data = d2l.FashionMNIST(batch_size=256)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.10471666666666668
# Test error: 0.12280000000000002

# %%
trainer = d2l.Trainer(max_epochs=15, num_gpus=1)
data = d2l.FashionMNIST(batch_size=72)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.06906666666666672
# Test error: 0.10209999999999997

# %%
trainer = d2l.Trainer(max_epochs=15, num_gpus=1)
data = d2l.FashionMNIST(batch_size=96)
model = LeNet(lr=0.1)
model.apply_init([next(iter(data.get_dataloader(True)))[0]], init_cnn)
trainer.fit(model, data)
model.evaluate_and_print_errors(data)
# Out:
# Train error: 0.06928333333333336
# Test error: 0.09899999999999998
